# %% [markdown]
# # Setup
# Run this at the start of each session

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: numpy in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (2.4.3)
# Requirement already satisfied: pandas in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: matplotlib in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (3.10.8)
# Requirement already satisfied: scikit-learn in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from pandas->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/andrewmungai/.platformio/penv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 2)) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score

print('All imports loaded ')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'
