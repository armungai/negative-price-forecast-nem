# %% [markdown]
# # Packages Setup

# %% [markdown]
# Installs the required packages and prints the version of each installed package
#
# Packages included `nemosis`, `pandas`, `numpy`, `matplotlib`, `seaborn`, `scipy`, `statsmodels`, `scikit-learn`, `jupyterlab`, `ipykernel`, `arch`
#
# **Recomended all memebers use Virtual Enviroment**

# %% [markdown]
# ### Step 1 — Install the required packages
# This uses `%pip` so the packages are installed into the **currently selected notebook kernel**.

# %%
# %pip install --upgrade pip
# %pip install nemosis pandas numpy matplotlib seaborn scipy statsmodels scikit-learn jupyterlab ipykernel arch rpy2 tabulate

# %% [markdown]
# ### Step 2 — Print versions

# %%
import sys
import platform
from importlib.metadata import version, PackageNotFoundError

packages = [
    "nemosis",
    "pandas",
    "numpy",
    "matplotlib",
    "seaborn",
    "scipy",
    "statsmodels",
    "scikit-learn",
    "jupyterlab",
    "ipykernel",
    "pip",
    "setuptools",
    "wheel",
    "arch",
    "rpy2",
    "tabulate"
]

print("Python Version Information")
print("-" * 50)
print("Python version :", platform.python_version())
print("Executable     :", sys.executable)
print("Platform       :", platform.platform())
print()

print("Installed Package Versions")
print("-" * 50)
for pkg in packages:
    try:
        print(f"{pkg:<15} : {version(pkg)}")
    except PackageNotFoundError:
        print(f"{pkg:<15} : NOT INSTALLED")

# %% [markdown]
# ### Step 3 — Confirm the packages import

# %%
import nemosis
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import scipy
import statsmodels
import sklearn
import IPython
import arch
import rpy2
import tabulate

print("All required packages imported successfully.")

# %% [markdown]
# ### # Step 4 — Enable R support in ipynb

# %%
# Step 4 — Enable R support in Python notebook cells

# %load_ext rpy2.ipython

print("R support loaded successfully. You can now use %%R at the top of a cell.")

# %%
# %%R
# print(1 + 1)
# print("R WORKS")
